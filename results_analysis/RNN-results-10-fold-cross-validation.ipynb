# %% [markdown]
# ## Results 10-fold Cross-Validation - RNN

# %%
accuracies={}
fold_histories=[]
total_conf_matrix=np.zeros((10,10), dtype=int)
for i in range (10):
    input_dim_lte=60
    embedding_dim=8
    num_meta_classes=6

    fold_test_rnn=(i%10)+1
    test_rnn=df_mfcc[df_mfcc['fold']== fold_test_rnn]
    x_test_rnn=test_rnn.iloc[:,3:]
    y_test_rnn=test_rnn.iloc[:,1]

    fold_val_rnn=((i+1)%10)+1
    val_rnn=df_mfcc[df_mfcc['fold']== fold_val_rnn]
    x_val_rnn=val_rnn.iloc[:,3:]
    y_val_rnn=val_rnn.iloc[:,1]
    
    fold_train_lte = [f for f in range(1, 11) if f not in [fold_test_rnn, fold_val_rnn]]
    train_lte=df_mfcc[df_mfcc['fold'].isin(fold_train_lte)]
    x_train_lte=train_lte.iloc[:,3:]
    y_train_lte=train_lte.iloc[:,1]

    # obtain the meta-classes to train the embedding model
    y_train_lte=get_meta_classes(y_train_lte).astype('int64')

    y_train_lte_one_hot=tf.keras.utils.to_categorical(y_train_lte,num_classes=num_meta_classes)
    LTE_model= build_LTE_model(input_dim=input_dim_lte, embedding_dim=embedding_dim, num_meta_classes=num_meta_classes)
    LTE_model.fit(x_train_lte, y_train_lte_one_hot, epochs=100, batch_size=128, validation_split=0.2,callbacks=[
        EarlyStopping(monitor='val_loss',patience=10,restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
    ])

    embedding_model= tf.keras.models.Model(inputs=LTE_model.input, outputs=LTE_model.layers[1].output)

    #--------------------------------------------------------------Train dataset preparation------------------------------------------------------

    train_rnn=df_mfcc[~df_mfcc['fold'].isin([fold_train_lte, fold_test_rnn, fold_val_rnn])].reset_index(drop=True)
    df_files_names=pd.DataFrame(train_rnn['audio_name'],columns=['audio_name'])
    x_train_rnn=train_rnn.iloc[:,3:]
    y_train_rnn=train_rnn.iloc[:,1]

    #print(f"Shape of LTE features: {x_train_rnn.shape}")  #--------------------------COMMENT THIS LINE TO NOT USE EMBEDDINGS-----------------------
    print(f"Shape of MFCC features: {x_train_rnn.shape}")

    # reshape dataset so that it is compatible with the RNN input
    #x_train_rnn = pd.DataFrame(x_train_rnn, columns=[f"LTE_feature_{i}" for i in range(x_train_rnn.shape[1])]) #----COMMENT THIS LINE TO NOT USE EMBEDDINGS--

    # allow a direct link between x_train_rnn and df_files_names
    x_train_rnn=x_train_rnn.reset_index(drop=True)
    x_train_rnn['audio_name'] = df_files_names['audio_name'].values
    y_train_rnn=y_train_rnn.to_frame(name='classID')

    # allow a direct link between y_train_rnn and df_files_names
    y_train_rnn=y_train_rnn.reset_index(drop=True)
    y_train_rnn['audio_name'] = df_files_names['audio_name'].values
    print(f"Shape of training dataset features: {x_train_rnn.shape}")
    print(f"Shape of training dataset labels: {y_train_rnn.shape}")
    
    # change the shape of y_train_rnn so that it is training-compatible
    y_train_rnn=y_train_rnn.groupby('audio_name', as_index=False)['classID'].first()
    y_train_rnn=y_train_rnn['classID']
    
    # change the shape of x_train_rnn to be compatible with training input
    feature_columns = [col for col in x_train_rnn.columns if col != 'audio_name']
    grouped = x_train_rnn.groupby('audio_name')
    
    reshaped_data=[]
    
    for name, group in grouped:
        features=group[feature_columns].values
        
        # 33 is the number of time_steps used to extract MFCC features for a 4-second audio
        if(features.shape[0]!=33):
            raise ValueError(f"The number of time_steps for audio {name} is not equal to the expected value. Expected 33 time_steps per audio, received {features.shape[0]}")
        
        reshaped_data.append(features)
    
    x_train_rnn=np.stack(reshaped_data, axis=0)
    
    print(f"Shape of training dataset features after reshaping: {x_train_rnn.shape}")

    x_train_rnn_aug = []
    for spec in x_train_rnn:
        x_train_rnn_aug.append(spec_augment_numpy(spec))
    x_train_rnn = np.stack(x_train_rnn_aug, axis=0)
    print("Data augmentation completed!")
    
    y_train_rnn_one_hot=tf.keras.utils.to_categorical(y_train_rnn,num_classes=10)
    print(f"Shape of training dataset labels after reshaping {y_train_rnn_one_hot.shape}")

    #--------------------------------------------------------------Test dataset preparation------------------------------------------------------

    df_files_names=pd.DataFrame(test_rnn['audio_name'],columns=['audio_name']).reset_index(drop=True)

    #x_test_rnn = embedding_model.predict(x_test_rnn) #------------COMMENT THIS LINE TO NOT USE EMBEDDINGS----------
    print(f"Shape of MFCC features : {x_test_rnn.shape}")

    #x_test_rnn = pd.DataFrame(x_test_rnn, columns=[f"LTE_feature_{i}" for i in range(x_test_rnn.shape[1])]) #---COMMENT TO NOT USE EMBEDDINGS----
    x_test_rnn=x_test_rnn.reset_index(drop=True)
    x_test_rnn['audio_name'] = df_files_names['audio_name'].values
    
    y_test_rnn=y_test_rnn.to_frame(name='classID')

    # allow a direct link between y_test_rnn and df_files_names
    y_test_rnn=y_test_rnn.reset_index(drop=True)
    y_test_rnn['audio_name'] = df_files_names['audio_name'].values
    print(f"Shape of test dataset features: {x_test_rnn.shape}")
    print(f"Shape of test dataset labels: {y_test_rnn.shape}")
    
    # change the shape of y_test_rnn to be compatible with evaluation
    y_test_rnn=y_test_rnn.groupby('audio_name', as_index=False)['classID'].first()
    y_test_rnn=y_test_rnn['classID']
    
    # reshape test features
    feature_columns = [col for col in x_test_rnn.columns if col != 'audio_name']
    grouped = x_test_rnn.groupby('audio_name')
    
    reshaped_data=[]
    
    for name, group in grouped:
        features=group[feature_columns].values
        if(features.shape[0]!=33):
            raise ValueError(f"The number of time_steps for audio {name} is not equal to expected. Expected 33, got {features.shape[0]}")
        
        reshaped_data.append(features)
    
    x_test_rnn=np.stack(reshaped_data, axis=0)
    
    print(f"Shape of test dataset features after reshaping: {x_test_rnn.shape}")
    
    y_test_rnn_one_hot=tf.keras.utils.to_categorical(y_test_rnn,num_classes=10)
    print(f"Shape of test dataset labels after reshaping {y_test_rnn_one_hot.shape}")

    #--------------------------------------------------------------Validation dataset preparation------------------------------------------------------

    df_files_names=pd.DataFrame(val_rnn['audio_name'],columns=['audio_name']).reset_index(drop=True)

    #x_val_rnn = embedding_model.predict(x_val_rnn) 
    print(f"Shape of MFCC features : {x_val_rnn.shape}")

    x_val_rnn=x_val_rnn.reset_index(drop=True)
    x_val_rnn['audio_name'] = df_files_names['audio_name'].values

    y_val_rnn=y_val_rnn.to_frame(name='classID')

    y_val_rnn=y_val_rnn.reset_index(drop=True)
    y_val_rnn['audio_name'] = df_files_names['audio_name'].values
    print(f"Shape of validation dataset features: {x_val_rnn.shape}")
    print(f"Shape of validation dataset labels: {y_val_rnn.shape}")

    # reorganize y
    y_val_rnn=y_val_rnn.groupby('audio_name', as_index=False)['classID'].first()
    y_val_rnn=y_val_rnn['classID']

    # reshape validation features
    feature_columns = [col for col in x_val_rnn.columns if col != 'audio_name']
    grouped = x_val_rnn.groupby('audio_name')

    reshaped_data=[]

    for name, group in grouped:
        features=group[feature_columns].values
        if(features.shape[0]!=33):
            raise ValueError(f"The number of time_steps for audio {name} is not equal to expected. Expected 33, got {features.shape[0]}")

        reshaped_data.append(features)

    x_val_rnn=np.stack(reshaped_data, axis=0)

    print(f"Shape of validation dataset features after reshaping: {x_val_rnn.shape}")

    y_val_rnn_one_hot=tf.keras.utils.to_categorical(y_val_rnn,num_classes=10)
    print(f"Shape of validation dataset labels after reshaping {y_val_rnn_one_hot.shape}")

    #--------------------------------------------------------------------------------------------------------------------

    # -------------------------
    # Compile with AdamW and label smoothing
    # -------------------------
    rnn_model = create_improved_rnn(
        input_dim=input_dim,
        hidden_dim=hidden_dim,
        output_dim=output_dim,
        num_layers=num_layers,
        dropout_rate=dropout_rate,
        l2_reg=l2_reg
    )

    optimizer = AdamW(learning_rate=1e-3, weight_decay=1e-4)
    loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True, label_smoothing=0.1)

    rnn_model.compile(optimizer=optimizer, loss=loss, metrics=["accuracy"])

    # -------------------------
    # Prepare tf.data datasets
    # -------------------------
    train_steps = int(np.ceil(len(x_train_rnn) / batch_size))
    val_steps = int(np.ceil(len(x_val_rnn) / batch_size))

    train_ds = tf.data.Dataset.from_generator(
        lambda: train_generator(x_train_rnn, y_train_rnn_one_hot, batch_size),
        output_signature=(
            tf.TensorSpec(shape=(None, None, input_dim), dtype=tf.float32),
            tf.TensorSpec(shape=(None, output_dim), dtype=tf.float32),
        )
    ).prefetch(tf.data.AUTOTUNE)

    val_ds = tf.data.Dataset.from_generator(
        lambda: val_generator(x_val_rnn, y_val_rnn_one_hot, batch_size),
        output_signature=(
            tf.TensorSpec(shape=(None, None, input_dim), dtype=tf.float32),
            tf.TensorSpec(shape=(None, output_dim), dtype=tf.float32),
        )
    ).prefetch(tf.data.AUTOTUNE)

    # -------------------------
    # Callbacks
    # -------------------------
    callbacks = [
        EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True),
        ReduceLROnPlateau(monitor="val_loss", factor=0.75, patience=5, min_lr=1e-6)
    ]

    # -------------------------
    # Fit
    # -------------------------
    history = rnn_model.fit(
        train_ds,
        steps_per_epoch=train_steps,
        epochs=max_epochs,
        validation_data=val_ds,
        validation_steps=val_steps,
        callbacks=callbacks
    )

    #--------------------------------------------------------------------------------------------------------------------

    # Normalize each spectrogram (T=33, F=60)
    x_test_norm = np.zeros_like(x_test_rnn, dtype=np.float32)

    for i in range(len(x_test_rnn)):
        x_test_norm[i] = per_feature_normalize(x_test_rnn[i])

    y_pred=rnn_model.predict(x_test_norm)

    y_pred_labels=np.argmax(y_pred, axis=1)
    y_test_labels=np.argmax(y_test_rnn_one_hot,axis=1)
    
    conf_matrix= confusion_matrix(y_true=y_test_labels, y_pred=y_pred_labels)
    total_conf_matrix=np.add(total_conf_matrix,conf_matrix)

    # Total correct predictions are the diagonal elements of the confusion matrix
    correct_predictions = np.trace(conf_matrix)
    total_predictions = np.sum(conf_matrix)  
    accuracy = correct_predictions / total_predictions
    print(f"Accuracy: {accuracy:.4f}")
    accuracies[f'Fold{i+1}']=accuracy
    
    conf_matrix = confusion_matrix(y_true=y_test_labels, y_pred=y_pred_labels)

    original_labels = {
        0: 'air_conditioner',
        1: 'car_horn',
        2: 'children_playing',
        3: 'dog_bark',
        4: 'drilling',
        5: 'engine_idling',
        6: 'gun_shot',
        7: 'jackhammer',
        8: 'siren',
        9: 'street_music'
    }

    class_names = [original_labels[i] for i in range(len(conf_matrix))]
    
    plt.figure(figsize=(10, 8))

    ax = sns.heatmap(
        conf_matrix,
        cmap='Blues',
        cbar=True,
        xticklabels=class_names,
        yticklabels=class_names
    )

    for i in range(conf_matrix.shape[0]):
        for j in range(conf_matrix.shape[1]):
            value = conf_matrix[i, j]
            ax.text(
                j + 0.5,
                i + 0.5,
                str(value),
                ha='center',
                va='center',
                fontsize=12,
            )

    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.tight_layout()
    plt.show()
    
    print("\nClassification Report")
    print(classification_report(y_true=y_test_labels, y_pred=y_pred_labels))
    
    plot_fold_results(history, y_test_labels, y_pred_labels, class_names, fold_number=1)
# Out:
# Epoch 1/100
# 1438/1438 [==============================] - 1s 497us/step - loss: 4.3310 - accuracy: 0.6265 - val_loss: 0.9723 - val_accuracy: 0.6421 - lr: 0.0010
# Epoch 2/100
# 1438/1438 [==============================] - 1s 431us/step - loss: 0.7717 - accuracy: 0.7197 - val_loss: 0.9188 - val_accuracy: 0.6518 - lr: 0.0010
# Epoch 3/100
# 1438/1438 [==============================] - 1s 455us/step - loss: 0.7344 - accuracy: 0.7339 - val_loss: 0.8866 - val_accuracy: 0.6647 - lr: 0.0010
# Epoch 4/100
# 1438/1438 [==============================] - 1s 431us/step - loss: 0.7053 - accuracy: 0.7455 - val_loss: 0.8706 - val_accuracy: 0.6678 - lr: 0.0010
# Epoch 5/100
# 1438/1438 [==============================] - 1s 443us/step - loss: 0.6899 - accuracy: 0.7500 - val_loss: 0.8472 - val_accuracy: 0.6798 - lr: 0.0010
# Epoch 6/100
# 1438/1438 [==============================] - 1s 446us/step - loss: 0.6765 - accuracy: 0.7553 - val_loss: 0.8599 - val_accuracy: 0.6805 - lr: 0.0010
# Epoch 7/100
# 1438/1438 [==============================] - 1s 446us/step - loss: 0.6680 - accuracy: 0.7593 - val_loss: 0.8501 - val_accuracy: 0.6884 - lr: 0.0010
# Epoch 8/100
# 1438/1438 [==============================] - 1s 532us/step - loss: 0.6625 - accuracy: 0.7608 - val_loss: 0.8311 - val_accuracy: 0.6945 - lr: 0.0010
# Epoch 9/100
# 1438/1438 [==============================] - 1s 500us/step - loss: 0.6567 - accuracy: 0.7640 - val_loss: 0.8364 - val_accuracy: 0.6934 - lr: 0.0010
# Epoch 10/100
# 1438/1438 [==============================] - 1s 463us/step - loss: 0.6517 - accuracy: 0.7638 - val_loss: 0.8415 - val_accuracy: 0.6846 - lr: 0.0010
# Epoch 11/100
# 1438/1438 [==============================] - 1s 470us/step - loss: 0.6478 - accuracy: 0.7659 - val_loss: 0.8353 - val_accuracy: 0.6510 - lr: 0.0010
# Epoch 12/100
# 1438/1438 [==============================] - 1s 478us/step - loss: 0.6444 - accuracy: 0.7660 - val_loss: 0.8326 - val_accuracy: 0.6909 - lr: 0.0010
# Epoch 13/100
# 1438/1438 [==============================] - 1s 459us/step - loss: 0.6411 - accuracy: 0.7676 - val_loss: 0.8329 - val_accuracy: 0.6947 - lr: 0.0010
# Epoch 14/100
# 1438/1438 [==============================] - 1s 452us/step - loss: 0.6310 - accuracy: 0.7725 - val_loss: 0.8179 - val_accuracy: 0.7035 - lr: 5.0000e-04
# Epoch 15/100
# 1438/1438 [==============================] - 1s 453us/step - loss: 0.6294 - accuracy: 0.7732 - val_loss: 0.8127 - val_accuracy: 0.6987 - lr: 5.0000e-04
# Epoch 16/100
# 1438/1438 [==============================] - 1s 448us/step - loss: 0.6281 - accuracy: 0.7731 - val_loss: 0.8118 - val_accuracy: 0.7028 - lr: 5.0000e-04
# Epoch 17/100
# 1438/1438 [==============================] - 1s 480us/step - loss: 0.6266 - accuracy: 0.7742 - val_loss: 0.8229 - val_accuracy: 0.7006 - lr: 5.0000e-04
# Epoch 18/100
# 1438/1438 [==============================] - 1s 450us/step - loss: 0.6250 - accuracy: 0.7742 - val_loss: 0.8278 - val_accuracy: 0.6985 - lr: 5.0000e-04
# Epoch 19/100
# 1438/1438 [==============================] - 1s 441us/step - loss: 0.6236 - accuracy: 0.7746 - val_loss: 0.8367 - val_accuracy: 0.6953 - lr: 5.0000e-04
# Epoch 20/100
# 1438/1438 [==============================] - 1s 476us/step - loss: 0.6224 - accuracy: 0.7749 - val_loss: 0.8303 - val_accuracy: 0.6998 - lr: 5.0000e-04
# Epoch 21/100
# 1438/1438 [==============================] - 1s 449us/step - loss: 0.6222 - accuracy: 0.7751 - val_loss: 0.8343 - val_accuracy: 0.6993 - lr: 5.0000e-04
# Epoch 22/100
# 1438/1438 [==============================] - 1s 441us/step - loss: 0.6169 - accuracy: 0.7771 - val_loss: 0.8338 - val_accuracy: 0.6977 - lr: 2.5000e-04
# Epoch 23/100
# 1438/1438 [==============================] - 1s 445us/step - loss: 0.6166 - accuracy: 0.7771 - val_loss: 0.8350 - val_accuracy: 0.6974 - lr: 2.5000e-04
# Epoch 24/100
# 1438/1438 [==============================] - 1s 450us/step - loss: 0.6161 - accuracy: 0.7774 - val_loss: 0.8333 - val_accuracy: 0.6976 - lr: 2.5000e-04
# Epoch 25/100
# 1438/1438 [==============================] - 1s 441us/step - loss: 0.6160 - accuracy: 0.7769 - val_loss: 0.8528 - val_accuracy: 0.6945 - lr: 2.5000e-04
# Epoch 26/100
# 1438/1438 [==============================] - 1s 468us/step - loss: 0.6155 - accuracy: 0.7774 - val_loss: 0.8260 - val_accuracy: 0.6983 - lr: 2.5000e-04
# Shape of MFCC features: (230043, 60)
# Shape of training dataset features: (230043, 61)
# Shape of training dataset labels: (230043, 2)
# Shape of training dataset features after reshaping: (6971, 33, 60)
# Data augmentation completed!
# Shape of training dataset labels after reshaping (6971, 10)
# Shape of MFCC features : (28809, 60)
# Shape of test dataset features: (28809, 61)
# Shape of test dataset labels: (28809, 2)
# Shape of test dataset features after reshaping: (873, 33, 60)
# Shape of test dataset labels after reshaping (873, 10)
# Shape of MFCC features : (29304, 60)
# Shape of validation dataset features: (29304, 61)
# Shape of validation dataset labels: (29304, 2)
# Shape of validation dataset features after reshaping: (888, 33, 60)
# Shape of validation dataset labels after reshaping (888, 10)
# 2025-11-30 19:54:49.457283: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:54:49.457936: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:54:49.458614: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 19:54:49.519512: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-11-30 19:54:49.534905: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:54:49.535446: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:54:49.535984: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 19:54:49.633799: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:54:49.634407: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:54:49.634956: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1/50
# 2025-11-30 19:54:49.699313: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-11-30 19:54:49.714743: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:54:49.715322: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:54:49.715843: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 19:54:49.784201: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2025-11-30 19:54:49.893543: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:54:49.894355: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:54:49.895010: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 19:54:49.982414: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-11-30 19:54:50.005020: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:54:50.005783: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:54:50.006494: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 19:54:51.968886: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:54:51.970395: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:54:51.971247: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 19:54:52.048637: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-11-30 19:54:52.070730: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:54:52.071406: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:54:52.072054: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 19:54:52.383431: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-11-30 19:54:52.629621: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-11-30 19:54:53.043287: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:54:53.044346: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:54:53.045056: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 19:54:53.123575: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-11-30 19:54:53.142900: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:54:53.143551: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:54:53.144155: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 19:54:53.244848: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:54:53.245795: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:54:53.246600: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 19:54:53.321866: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-11-30 19:54:53.340565: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:54:53.341205: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:54:53.341842: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 19:54:53.650439: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-11-30 19:54:53.895134: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 109/109 [==============================] - ETA: 0s - loss: 2.0983 - accuracy: 0.3274
# 2025-11-30 19:55:06.217848: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2025-11-30 19:55:06.340230: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:55:06.341193: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:55:06.341948: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 19:55:06.417903: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-11-30 19:55:06.444347: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:55:06.445371: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:55:06.446083: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 19:55:06.546136: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:55:06.546906: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:55:06.547576: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 19:55:06.618456: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-11-30 19:55:06.642016: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:55:06.642931: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:55:06.643672: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 109/109 [==============================] - 18s 111ms/step - loss: 2.0983 - accuracy: 0.3274 - val_loss: 1.7914 - val_accuracy: 0.4403 - lr: 0.0010
# Epoch 2/50
# 109/109 [==============================] - 12s 111ms/step - loss: 1.7570 - accuracy: 0.5335 - val_loss: 1.6976 - val_accuracy: 0.5068 - lr: 0.0010
# Epoch 3/50
# 109/109 [==============================] - 12s 112ms/step - loss: 1.5932 - accuracy: 0.6226 - val_loss: 1.6289 - val_accuracy: 0.5315 - lr: 0.0010
# Epoch 4/50
# 109/109 [==============================] - 11s 105ms/step - loss: 1.5555 - accuracy: 0.6725 - val_loss: 1.5817 - val_accuracy: 0.5484 - lr: 0.0010
# Epoch 5/50
# 109/109 [==============================] - 12s 110ms/step - loss: 1.4531 - accuracy: 0.7018 - val_loss: 1.5866 - val_accuracy: 0.5484 - lr: 0.0010
# Epoch 6/50
# 109/109 [==============================] - 13s 116ms/step - loss: 1.3905 - accuracy: 0.7454 - val_loss: 1.6182 - val_accuracy: 0.5360 - lr: 0.0010
# Epoch 7/50
# 109/109 [==============================] - 12s 111ms/step - loss: 1.4112 - accuracy: 0.7388 - val_loss: 1.5986 - val_accuracy: 0.5518 - lr: 0.0010
# Epoch 8/50
# 109/109 [==============================] - 13s 118ms/step - loss: 1.3356 - accuracy: 0.7768 - val_loss: 1.6036 - val_accuracy: 0.5484 - lr: 0.0010
# Epoch 9/50
# 109/109 [==============================] - 13s 122ms/step - loss: 1.3108 - accuracy: 0.7987 - val_loss: 1.6642 - val_accuracy: 0.5146 - lr: 0.0010
# Epoch 10/50
# 109/109 [==============================] - 13s 124ms/step - loss: 1.3057 - accuracy: 0.8072 - val_loss: 1.6216 - val_accuracy: 0.5450 - lr: 7.5000e-04
# Epoch 11/50
# 109/109 [==============================] - 14s 129ms/step - loss: 1.2215 - accuracy: 0.8369 - val_loss: 1.6342 - val_accuracy: 0.5495 - lr: 7.5000e-04
# Epoch 12/50
# 109/109 [==============================] - 15s 140ms/step - loss: 1.2250 - accuracy: 0.8461 - val_loss: 1.6491 - val_accuracy: 0.5529 - lr: 7.5000e-04
# Epoch 13/50
# 109/109 [==============================] - 14s 125ms/step - loss: 1.1713 - accuracy: 0.8659 - val_loss: 1.6212 - val_accuracy: 0.5495 - lr: 7.5000e-04
# Epoch 14/50
# 109/109 [==============================] - 12s 107ms/step - loss: 1.2186 - accuracy: 0.8624 - val_loss: 1.6112 - val_accuracy: 0.5541 - lr: 7.5000e-04
# 2025-11-30 19:57:54.316752: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:57:54.317856: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:57:54.318595: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 19:57:54.399437: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-11-30 19:57:54.421379: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:57:54.422277: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:57:54.423034: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 19:57:54.531767: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:57:54.532746: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:57:54.533452: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 19:57:54.606367: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-11-30 19:57:54.626538: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:57:54.627349: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:57:54.628040: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 28/28 [==============================] - 1s 15ms/step
# Accuracy: 0.5189
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.58      0.28      0.38       100
#            1       0.86      0.89      0.88        36
#            2       0.72      0.41      0.52       100
#            3       0.67      0.68      0.67       100
#            4       0.26      0.38      0.31       100
#            5       0.46      0.45      0.46        96
#            6       0.59      0.74      0.66        35
#            7       0.36      0.28      0.31       120
#            8       0.58      0.99      0.73        86
#            9       0.55      0.59      0.57       100
#
#     accuracy                           0.52       873
#    macro avg       0.56      0.57      0.55       873
# weighted avg       0.54      0.52      0.51       873
# Epoch 1/100
# 1428/1428 [==============================] - 1s 496us/step - loss: 1.6489 - accuracy: 0.6401 - val_loss: 0.9320 - val_accuracy: 0.6265 - lr: 0.0010
# Epoch 2/100
# 1428/1428 [==============================] - 1s 440us/step - loss: 0.8016 - accuracy: 0.6994 - val_loss: 0.8836 - val_accuracy: 0.6503 - lr: 0.0010
# Epoch 3/100
# 1428/1428 [==============================] - 1s 437us/step - loss: 0.7478 - accuracy: 0.7157 - val_loss: 0.8518 - val_accuracy: 0.6767 - lr: 0.0010
# Epoch 4/100
# 1428/1428 [==============================] - 1s 437us/step - loss: 0.7103 - accuracy: 0.7298 - val_loss: 0.8314 - val_accuracy: 0.6797 - lr: 0.0010
# Epoch 5/100
# 1428/1428 [==============================] - 1s 460us/step - loss: 0.6855 - accuracy: 0.7428 - val_loss: 0.8276 - val_accuracy: 0.6907 - lr: 0.0010
# Epoch 6/100
# 1428/1428 [==============================] - 1s 437us/step - loss: 0.6707 - accuracy: 0.7507 - val_loss: 0.8173 - val_accuracy: 0.6908 - lr: 0.0010
# Epoch 7/100
# 1428/1428 [==============================] - 1s 437us/step - loss: 0.6629 - accuracy: 0.7542 - val_loss: 0.8281 - val_accuracy: 0.6820 - lr: 0.0010
# Epoch 8/100
# 1428/1428 [==============================] - 1s 438us/step - loss: 0.6563 - accuracy: 0.7567 - val_loss: 0.8230 - val_accuracy: 0.6885 - lr: 0.0010
# Epoch 9/100
# 1428/1428 [==============================] - 1s 439us/step - loss: 0.6528 - accuracy: 0.7576 - val_loss: 0.8212 - val_accuracy: 0.6878 - lr: 0.0010
# Epoch 10/100
# 1428/1428 [==============================] - 1s 438us/step - loss: 0.6483 - accuracy: 0.7584 - val_loss: 0.8488 - val_accuracy: 0.6813 - lr: 0.0010
# Epoch 11/100
# 1428/1428 [==============================] - 1s 436us/step - loss: 0.6440 - accuracy: 0.7608 - val_loss: 0.8325 - val_accuracy: 0.6815 - lr: 0.0010
# Epoch 12/100
# 1428/1428 [==============================] - 1s 459us/step - loss: 0.6373 - accuracy: 0.7642 - val_loss: 0.8301 - val_accuracy: 0.6870 - lr: 5.0000e-04
# Epoch 13/100
# 1428/1428 [==============================] - 1s 437us/step - loss: 0.6353 - accuracy: 0.7644 - val_loss: 0.8270 - val_accuracy: 0.6835 - lr: 5.0000e-04
# Epoch 14/100
# 1428/1428 [==============================] - 1s 438us/step - loss: 0.6334 - accuracy: 0.7653 - val_loss: 0.8274 - val_accuracy: 0.6903 - lr: 5.0000e-04
# Epoch 15/100
# 1428/1428 [==============================] - 1s 439us/step - loss: 0.6308 - accuracy: 0.7663 - val_loss: 0.8195 - val_accuracy: 0.6919 - lr: 5.0000e-04
# Epoch 16/100
# 1428/1428 [==============================] - 1s 439us/step - loss: 0.6273 - accuracy: 0.7680 - val_loss: 0.8398 - val_accuracy: 0.6793 - lr: 5.0000e-04
# Shape of MFCC features: (228327, 60)
# Shape of training dataset features: (228327, 61)
# Shape of training dataset labels: (228327, 2)
# Shape of training dataset features after reshaping: (6919, 33, 60)
# Data augmentation completed!
# Shape of training dataset labels after reshaping (6919, 10)
# Shape of MFCC features : (29304, 60)
# Shape of test dataset features: (29304, 61)
# Shape of test dataset labels: (29304, 2)
# Shape of test dataset features after reshaping: (888, 33, 60)
# Shape of test dataset labels after reshaping (888, 10)
# Shape of MFCC features : (30525, 60)
# Shape of validation dataset features: (30525, 61)
# Shape of validation dataset labels: (30525, 2)
# Shape of validation dataset features after reshaping: (925, 33, 60)
# Shape of validation dataset labels after reshaping (925, 10)
# 2025-11-30 19:58:08.251116: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:58:08.252001: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:58:08.252684: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 19:58:08.317819: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-11-30 19:58:08.333967: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:58:08.334524: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:58:08.335048: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 19:58:08.431926: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:58:08.432464: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:58:08.432946: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1/50
# 2025-11-30 19:58:08.498748: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-11-30 19:58:08.514689: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:58:08.515327: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 19:58:08.515858: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 19:58:08.580482: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2025-11-30 19:58:08.693329: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 19:58:08.694079: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# ...
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 20:45:06.195250: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-11-30 20:45:06.222611: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 20:45:06.223587: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 20:45:06.224282: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 20:45:06.373619: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 20:45:06.374423: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 20:45:06.375298: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 20:45:06.495030: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-11-30 20:45:06.517748: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 20:45:06.518477: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 20:45:06.519275: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 110/110 [==============================] - 17s 119ms/step - loss: 2.0571 - accuracy: 0.3577 - val_loss: 1.8167 - val_accuracy: 0.4261 - lr: 0.0010
# Epoch 2/50
# 110/110 [==============================] - 12s 108ms/step - loss: 1.7141 - accuracy: 0.5595 - val_loss: 1.7396 - val_accuracy: 0.4754 - lr: 0.0010
# Epoch 3/50
# 110/110 [==============================] - 12s 107ms/step - loss: 1.6174 - accuracy: 0.6252 - val_loss: 1.7336 - val_accuracy: 0.4960 - lr: 0.0010
# Epoch 4/50
# 110/110 [==============================] - 12s 107ms/step - loss: 1.5002 - accuracy: 0.6974 - val_loss: 1.7351 - val_accuracy: 0.5040 - lr: 0.0010
# Epoch 5/50
# 110/110 [==============================] - 12s 107ms/step - loss: 1.4673 - accuracy: 0.7119 - val_loss: 1.6910 - val_accuracy: 0.5166 - lr: 0.0010
# Epoch 6/50
# 110/110 [==============================] - 12s 108ms/step - loss: 1.3804 - accuracy: 0.7549 - val_loss: 1.6434 - val_accuracy: 0.5315 - lr: 0.0010
# Epoch 7/50
# 110/110 [==============================] - 12s 108ms/step - loss: 1.3619 - accuracy: 0.7774 - val_loss: 1.7097 - val_accuracy: 0.5189 - lr: 0.0010
# Epoch 8/50
# 110/110 [==============================] - 12s 108ms/step - loss: 1.3271 - accuracy: 0.7841 - val_loss: 1.7276 - val_accuracy: 0.5029 - lr: 0.0010
# Epoch 9/50
# 110/110 [==============================] - 12s 107ms/step - loss: 1.3316 - accuracy: 0.8001 - val_loss: 1.6757 - val_accuracy: 0.5189 - lr: 0.0010
# Epoch 10/50
# 110/110 [==============================] - 11s 102ms/step - loss: 1.2930 - accuracy: 0.8069 - val_loss: 1.7015 - val_accuracy: 0.5074 - lr: 0.0010
# Epoch 11/50
# 110/110 [==============================] - 11s 103ms/step - loss: 1.2548 - accuracy: 0.8291 - val_loss: 1.6785 - val_accuracy: 0.5315 - lr: 0.0010
# Epoch 12/50
# 110/110 [==============================] - 11s 104ms/step - loss: 1.3035 - accuracy: 0.8273 - val_loss: 1.6530 - val_accuracy: 0.5258 - lr: 7.5000e-04
# Epoch 13/50
# 110/110 [==============================] - 12s 105ms/step - loss: 1.2025 - accuracy: 0.8654 - val_loss: 1.6651 - val_accuracy: 0.5235 - lr: 7.5000e-04
# Epoch 14/50
# 110/110 [==============================] - 12s 108ms/step - loss: 1.2271 - accuracy: 0.8647 - val_loss: 1.6472 - val_accuracy: 0.5338 - lr: 7.5000e-04
# Epoch 15/50
# 110/110 [==============================] - 12s 107ms/step - loss: 1.2012 - accuracy: 0.8520 - val_loss: 1.6645 - val_accuracy: 0.5384 - lr: 7.5000e-04
# Epoch 16/50
# 110/110 [==============================] - 12s 109ms/step - loss: 1.1911 - accuracy: 0.8733 - val_loss: 1.6318 - val_accuracy: 0.5281 - lr: 7.5000e-04
# Epoch 17/50
# 110/110 [==============================] - 12s 108ms/step - loss: 1.1438 - accuracy: 0.8921 - val_loss: 1.6563 - val_accuracy: 0.5349 - lr: 7.5000e-04
# Epoch 18/50
# 110/110 [==============================] - 12s 109ms/step - loss: 1.1915 - accuracy: 0.8757 - val_loss: 1.6650 - val_accuracy: 0.5200 - lr: 7.5000e-04
# Epoch 19/50
# 110/110 [==============================] - 12s 112ms/step - loss: 1.1688 - accuracy: 0.8812 - val_loss: 1.6675 - val_accuracy: 0.5361 - lr: 7.5000e-04
# Epoch 20/50
# 110/110 [==============================] - 13s 119ms/step - loss: 1.2146 - accuracy: 0.8634 - val_loss: 1.6545 - val_accuracy: 0.5372 - lr: 7.5000e-04
# Epoch 21/50
# 110/110 [==============================] - 12s 109ms/step - loss: 1.1526 - accuracy: 0.8835 - val_loss: 1.6070 - val_accuracy: 0.5487 - lr: 7.5000e-04
# Epoch 22/50
# 110/110 [==============================] - 12s 110ms/step - loss: 1.1784 - accuracy: 0.8781 - val_loss: 1.6294 - val_accuracy: 0.5498 - lr: 7.5000e-04
# Epoch 23/50
# 110/110 [==============================] - 12s 110ms/step - loss: 1.1945 - accuracy: 0.8778 - val_loss: 1.6303 - val_accuracy: 0.5441 - lr: 7.5000e-04
# Epoch 24/50
# 110/110 [==============================] - 12s 111ms/step - loss: 1.1775 - accuracy: 0.8884 - val_loss: 1.6373 - val_accuracy: 0.5452 - lr: 7.5000e-04
# Epoch 25/50
# 110/110 [==============================] - 14s 124ms/step - loss: 1.1589 - accuracy: 0.8750 - val_loss: 1.6155 - val_accuracy: 0.5590 - lr: 7.5000e-04
# Epoch 26/50
# 110/110 [==============================] - 14s 127ms/step - loss: 1.1171 - accuracy: 0.9013 - val_loss: 1.6168 - val_accuracy: 0.5418 - lr: 7.5000e-04
# Epoch 27/50
# 110/110 [==============================] - 12s 106ms/step - loss: 1.0938 - accuracy: 0.9181 - val_loss: 1.6310 - val_accuracy: 0.5407 - lr: 5.6250e-04
# Epoch 28/50
# 110/110 [==============================] - 13s 114ms/step - loss: 1.0984 - accuracy: 0.9118 - val_loss: 1.6521 - val_accuracy: 0.5361 - lr: 5.6250e-04
# Epoch 29/50
# 110/110 [==============================] - 11s 103ms/step - loss: 1.1034 - accuracy: 0.9146 - val_loss: 1.6308 - val_accuracy: 0.5361 - lr: 5.6250e-04
# Epoch 30/50
# 110/110 [==============================] - 12s 112ms/step - loss: 1.0872 - accuracy: 0.9173 - val_loss: 1.6595 - val_accuracy: 0.5361 - lr: 5.6250e-04
# Epoch 31/50
# 110/110 [==============================] - 11s 103ms/step - loss: 1.0702 - accuracy: 0.9160 - val_loss: 1.6478 - val_accuracy: 0.5407 - lr: 5.6250e-04
# 2025-11-30 20:51:07.566037: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 20:51:07.567025: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 20:51:07.567726: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 20:51:07.647342: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-11-30 20:51:07.668199: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 20:51:07.668881: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 20:51:07.669550: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 20:51:07.771298: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 20:51:07.772199: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 20:51:07.772892: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-11-30 20:51:07.849611: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2025-11-30 20:51:07.869429: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-11-30 20:51:07.870085: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-11-30 20:51:07.870779: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 27/27 [==============================] - 1s 17ms/step
# Accuracy: 0.5926
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.60      0.66      0.63       100
#            1       0.87      0.82      0.84        33
#            2       0.43      0.69      0.53       100
#            3       0.74      0.68      0.71       100
#            4       0.41      0.54      0.46       100
#            5       0.75      0.41      0.53        93
#            6       0.80      1.00      0.89        32
#            7       0.60      0.55      0.58        96
#            8       0.72      0.41      0.52        83
#            9       0.64      0.55      0.59       100
#
#     accuracy                           0.59       837
#    macro avg       0.66      0.63      0.63       837
# weighted avg       0.63      0.59      0.59       837
